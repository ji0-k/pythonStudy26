# %%
#"key = value 순서값이 아닌 1:1 매칭으로 값이 정해져있음 {} 중괄호로 감싸게 된다
#{key1 : value1, key2 : value2 ....}
# 대부분 웹 프로그램 언어는 json이라는 값으로 처리하는데
# 유사한 형태이다.

dic = {"name" : "kkw", "age" : 40 }
#         K       v      k      v
type(dic)

print(dic["name"])
print(dic["age"])
# Out:
# kkw
# 40

# %%
a = {1:'hi'}
print(a[1]) #print(변수[kye])가 들어가서 value가 출력된다
# Out:
# hi

# %%
b = {"a" : [1, 2, 3]}
#     k       V
print(b["a"]) #집합처럼 사용 할 수 있다
# Out:
# [1, 2, 3]

# %%
print(b["a"][1]) #밸류안에 한 값만 원하면 [][] 두개 작성
# Out:
# 2

# %%
print(dic)
# Out:
# {'name': 'kkw', 'age': 40}

# %%
dic['email'] = "mbc@kkw.com" # dic.안에 추가 가능 kye = value 써서 추가

print(dic)
# Out:
# {'name': 'kkw', 'age': 40, 'email': 'mbc@kkw.com'}

# %%
#dic. 변수에 age를 삭제해보자. del을 사용하여
del dic["age"]
print(dic)
# Out:
# {'name': 'kkw', 'email': 'mbc@kkw.com'}

# %%
# 수정가능 = 으로 바꾼다
dic['name'] = "김dd"
print(dic)
# Out:
# {'name': '김dd', 'email': 'mbc@kkw.com'}

# %%
# 하나의 key에 여러가지 value 있을 수있으니

# %%
 dic = {'name':'pey', 'phone':'010-9999-1234', 'birth': '1118'}
 dic['name']
# Out:
# 'pey'

# %%
 dic['phone']
# Out:
# '010-9999-1234'

# %%
 dic['birth']
# Out:
# '1118'

# %%
# kye는 무조건 1, 1: n 가능 , n : 1 안됨, value는 n값가능 , key는 1 만 가진다
# kye는 []리스트로 쓸수 없다. value는 []리스트 가능

# %%
##kye 리스트 만들기 - keys : a.keys()
dic.keys()
# Out:
# dict_keys(['name', 'phone', 'birth'])

# %%
# key의 값들을 리스트로 생성하려면
dic.values()
# Out:
# dict_values(['pey', '010-9999-1234', '1118'])

# %%
#key와 value 의 쌍으로 튜플 처리 하려면
dic.items()
# Out:
# dict_items([('name', 'pey'), ('phone', '010-9999-1234'), ('birth', '1118')])

# %%
#get을 이용해 키를 넣으면 value값이 나오도록
dic.get("name")
# Out:
# 'pey'

# %%
#key에 해당하는 값을 가져올 때 없는키를 넣으면 , 에러가 뜨고 꺼진다 ( 꺼짐 방지는 다음 시간에)
dic["age"] #없는키 오류 발생 key error
#프로그램 실행중 치명적인 오류로 강제 종류 된다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 2
#       1 #key에 해당하는 값을 가져올 때 없는키를 넣으면
# ----> 2 dic["age"]
#
# KeyError: 'age'

# %%
dic.get("age","값없음")
#      key key가없을때 출력문
# Out:
# '값없음'

# %%
print(dic)
# Out:
# {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'}

# %%
"name" in dic # in명령어는 리스트나, 튜플, 디서너리 안에 값???
# Out:
# True

# %%
"add" in dic
# Out:
# False

# %%
"pey" in dic # vlaue 찾기하면 False로 뜬다 , key만 찾을 수 있다
# Out:
# False

# %%
#key를 이용해서 value - pop : 값을 꺼내와 변수에넣고 삭제한다
print(dic)
# Out:
# {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'}

# %%
birth = dic.pop('birth')  #birth항목 지우고 , 출력해줌
print(birth)
# Out:
# 1118

# %%
print(dic)
# Out:
# {'name': 'pey', 'phone': '010-9999-1234'}

# %%
age = dic.pop("age", "찾는값이 없습니다.")
age = dic.pop("age", "찾는값이 없습니다.")
print(age)
# Out:
# 찾는값이 없습니다.
