# %%
#문자열(String) 자료형
#연속된 문자들을 나열한다
# 큰따옴표 , 작은따옴표 안에 작성된 모든 글자를 문자열 취급한다.
# 따옴표로 만든 값은 직접 계산하면 안된다

kor= "100"
eng= "100"
mat = "100"


total = kor + eng + mat #따옴표 안에 숫자는 문자열로 인식됨으로 연산이안됨
print(total)
# Out:
# 100100100

# %%
# 문자열은 더하기 식이 진행되면 글자를 붙임
 a = " hello world "
 print (a)
# Out:
#   Cell In[2], line 2
#     a = " hello world "
#     ^
# IndentationError: unexpected indent

# %%
#문자열 만드는 방법 4가지
# " HELLO WORLD" 큰 따옴표 로 둘러싸기
# ' PYTHON IS FUN ' 작은 따옴표 로 둘러싸기
# ''' HI ''' 작은따옴표 3개를 연속으로 써서 양쪽 둘러싸기
#""" BYE """ 큰 따옴표 3개를 연속으러 써서 양쪽 둘러싸기

# %%
#문자열에 작은따옴표 표시할때 = 큰따옴표 양쪽 둘러싸고 안에 표시 Q 한코드안에 프린트 두번이상 ? , 하나라도 틀리면 아예 출력 안되는가
food = "Python's favorite food is perl"
print(food)

#작은따옴표로 둘러싸고 안에 표시
food2 = 'Python's favorite food is perl'
print(food2)
# Out:
#   Cell In[6], line 6
#     food2 = 'Python's favorite food is perl'
#                                            ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
# 문자열 안에 큰따옴표, 작은따옴표 표시해야할때
# 양쪽 큰따옴표로 둘러싸고 안에 작은따옴표 표시
# 양쪽 작은따옴표로 둘러싸고 안에 큰따옴표 표시
# 역슬래시를 이용해서 나 자체를 뜻하게함 \

# %%
#\t 문자열 사이에 탭간격을 줄때 사용
S = ("im\tso\tstarving")
print(S)
# Out:
# im	so	starving

# %%
a = ("hello 'big' world")
print (a)
# Out:
# hello 'big' world

# %%
b = 'python is "fun"'
print (b)
# Out:
# python is "fun"

# %%
c = """life is too short,
you need python"""
# 쌍따옴표 3개를 스면 줄바꿈도 먹힘
print (c)

# %%
menu = "환영합니다. 'MBC' 아카데미 성적처리 프로그램 입니다."
submenu = "1. 학생등록 2. 성적처리 3.성적보기 4. 종료"
print(menu)
print (submenu)
# Out:
# 환영합니다. 'MBC' 아카데미 성적처리 프로그램 입니다.
# 1. 학생등록 2. 성적처리 3.성적보기 4. 종료

# %%
menu = """
======================================================
환영합니다. 'MBC' 아카데미 성적처리 프로그램 입니다.
======================================================
1. 학생등록
2. 성적처리
3. 성적보기
4. 종료
>>>
"""
print(menu)
# Out:
# ...
# 환영합니다. 'MBC' 아카데미 성적처리 프로그램 입니다.
# ...
# 1. 학생등록
# 2. 성적처리
# 3. 성적보기
# 4. 종료
# >>>

# %%
submenu1 = '''
========================================
학생메뉴로 진입하셨습니다.
1. 학생전체보기
2. 학생자세히보기
3. 학생수정하기
4. 학생삭제하기
5. 상위메뉴로 진입
========================================
'''
print (submenu1)
# Out:
# ...
# 학생메뉴로 진입하셨습니다.
# 1. 학생전체보기
# 2. 학생자세히보기
# 3. 학생수정하기
# 4. 학생삭제하기
# 5. 상위메뉴로 진입
# ...

# %%
#                 회원     /    성정   /  게시판
# C create (생성) 회원 등록 / 성적 입력 / 새글등록
# R read (읽기) 전체(전체회원 / 저체성적) / 1개 (로그인 / 내성적보기) / (리스트 보기 / 자세히보기)
# U update (수정) 회원정보 수정 / 성적 수정하기 / 글 수정하기
# D delete (삭제) 회원 탈퇴 /  ???? / 판매완료

# %%
food = ' python' s  favorite food is perl (''
 print (food)
  # syntax 는 문법 오류
# Out:
#   Cell In[24], line 1
#     food = ' python' s  favorite food is perl (''
#                      ^
# SyntaxError: invalid syntax

# %%
# 이스케이프 코드 = 출력물 보기 좋게 정렬하는 용도#
# \n 문자열 안에서 줄을 바꿀때
# \t 탭 간격
# \\ \를 그대로 표현할때
#

# %%
#여러 줄인 문자열을 변수에 대입하고 싶을 때
food3=("""sexyfood\npizza\ncoffee""")
print(food3)
# Out:
# sexyfood
# pizza
# coffee

# %%
submenu2 = ("================================\n 성적처리메뉴로진입하셨습니다. \n 1. 학생성적등록 \n 2. 학생전체성적보기 \n 3. 학생개인성적보기 \n 4. 학생성적수정 \n 5. 학생자료백업 \n 상위메뉴 \n=================================")
print(submenu2)
# 역슬래시 영문 N (\n) 줄바꿈 기능
# Out:
# ...
#  성적처리메뉴로진입하셨습니다.
#  1. 학생성적등록
#  2. 학생전체성적보기
#  3. 학생개인성적보기
#  4. 학생성적수정
#  5. 학생자료백업
#  상위메뉴
# ...

# %%
#코드	설명
#\n	문자열 안에서 줄을 바꿀 때 사용
#\t	문자열 사이에 탭 간격을 줄 때 사용
#\\	\를 그대로 표현할 때 사용
#\'	작은따옴표(')를 그대로 표현할 때 사용
#\"	큰따옴표(")를 그대로 표현할 때 사용
#\r	캐리지 리턴(줄 바꿈 문자, 커서를 현재 줄의 가장 앞으로 이동)
#\f	폼 피드(줄 바꿈 문자, 커서를 현재 줄의 다음 줄로 이동)
#\a	벨 소리(출력할 때 PC 스피커에서 '삑' 소리가 난다)
#\b	백 스페이스
#\000	널 문자

# %%
# Menu3.py 파일을 생성하고 print 괄호 안에 "="*15 하면
# = 이 15번 반복하는 것을 볼 수 있다.

# %%
# 문자열의 길이를 구하는 len() 함수가있다.
# 입력 된 주민번호, ID/PW 글자수를 알아내거나 검증용으로 활용

inputSsn = "120604-2345678"
type(inputSsn) #변수안에 있는 데이터가 어떤종류인지 알때
# Out:
# str

# %%
len(inputSsn) # 변수안에 있는 데이터가 몇 글자인지 알때
# Out:
# 14

# %%
# 입력된 문자의 길이가 맞는지 검증
if len(inputSsn) == 14 : # 콜론 다음 줄에는 들여쓰기 확인해야 이어지는 문장됨
    print (" 주민번호 14글자가 잘 입력 되었습니다.") # 참
else:
    print (" 주민번호 14글자가 잘 못 입력 되었습니다.") # 거짓
# Out:
#  주민번호 14글자가 잘 못 입력 되었습니다.

# %%
#문자열 인덱싱(indexing) 0부터 문자를 넣어 각 문자의 주소 , 가르킨다
# 문자열 슬라이싱(slicing) 문자를 인덱스로 잘라 가져온다 , 필요한 부분 빼오는거 , AI사용시 많이 쓰임

# %%
word = " Life is too short , you need python "
len(word)
# Out:
# 37

# %%
word[3] # word 변수에 3번째 문자 열
# Out:
# 'f'

# %%
word[-1] #음수값 입력할 경우 뒤에서 부터 세어진 번째 문자열
# Out:
# ' '

# %%
# 문자열 슬라이싱
# 변수 [시작:-끝] 끝번호는 해당 문자를 포함하지않음
# word[0:3] 해석 -> 0 <= a < 3
word[1:5]
# Out:
# 'Life'

# %%
# 주민번호 앞 두자리를 생년으로 추출하여 year에 넣기
# 주민번호 3~4 자리를 생월로 추출 month
# 주민번호 5~6 자리를 생일로 추출 day
# 주민번호 8번째 한자리를 남여 추출 sex

# %%
inputSsn = "120604-1345678"
year = inputSsn[0:2]
month = inputSsn[2:4]
day = inputSsn[4:6]
sex = inputSsn[7]

# %%
print("생년" + year)
# Out:
# 생년12

# %%
print("생월" + month)
# Out:
# 생월06

# %%
print("생일" + day)
# Out:
# 생일04

# %%
if sex == 1 :
    print ("성별 남자")
else:
    print("성별 여자")
# 비교 할 조건이 2개 이상이기 때문에 부합하지 않음
# Out:
# 성별 여자

# %%
#주민번호를 이용해서 남여 구분을 위한 코드
#문자열로 인식된 숫자로 계산시 타입변화 필요

snumber=inputSsn[7]
print(snumber)
type(snumber)
snumber = int(snumber) # 문자가 숫자로 타입변환 진행 int (문자)
#type(snumber)

if snumber % 2 == 1 :
    sex = "성별 남자"
else:
    sex = "성별 여자"

print (sex)
# Out:
# 2
# 성별 여자

# %%
if snumber =  :
    sex = "1900년생 남자"
else:
    sex = "성별 여자"
print(sex)
# Out:
#   Cell In[104], line 1
#     if snumber = "1"+"5" :
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
if sunmber == 1 :
    yearif = "19" + year  #문자인 경우 + 기호는 붙임
elif sunmber == 2 :
    yearif = "19"+ year
elif sunmber == 5 :
    yearif = "19" + year
elif sunmber == 6 :
    yearif = "19" + year
elif sunmber == 0 :
    yearif = "잘못입력"
else :
    yearif = "20"+year
print(yearif)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 if sunmber == 1 :
#       2     yearif = "19" + year #문자인 경우 + 기호는 붙임
#       3 elif sunmber == 2 :
#
# NameError: name 'sunmber' is not defined
