# %%
# 생성 : 넣는거 등록 입력 새글등록
# 읽기 : 전체 전체 회원 전체 성적 리스트보기
#        1개 로그인 내성적 보기 자세히 보기
# 수정 : 수정 성적수정 글수정
# 삭제 : 탈퇴 ??????????

# %%
# 리스트란 표형식의 배열을 말한다
# IDs = ["kjy","yky","mbc"]
# PWs = ["1234", "4567", "7890"]
# Names = ["김지영", "윤경영", "엠비씨"]
# 리스트를 만들 때는 대활호[] 로 감싸주고 쉼표 ','로 구분한다.

# a = [] 빈 리스트를 생성한다. -> a = list() 빈 리스트 바로 만들기
# b = [1,2,3] 정수를 입력 할 수 있다.  -> b[1] => 2
# c = [1, 2, 'kjy', 'yky'] 와 같이 문자, 숫자 , 소수점 혼용하여 넣을 수 있다. (only python , java는 보안상 위험해서 X)
# d = [1, 2, ['kjy', '1234']] 2차원 리스트
# d 변수에서 kjy를 가져오고 싶으면? => d[2][0]
# f = [1, 2,  3차원리스트

# %%
# 리스트의 인덱싱 -> 문자열 인덱싱과 같다.
a = [ 1, 2, 3 ]
print(a)
# Out:
# [1, 2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
# 1

# %%
a[0] + a[2]
# 따옴표 없어서 숫자계산으로 나옴
# Out:
# 4

# %%
a[-1]
# Out:
# 3

# %%
b = [1,2,3,['a','b','c']] #2차원 리스트 3을 불러오면 a,b,c 전체가 나온다
b[3][2]
# Out:
# 'c'

# %%
b[-1][1]
# Out:
# 'b'

# %%
#리스트의 슬라이싱 -> 문자열의 슬라이싱과 같다.
c = [ 1,2,3,4,5,6]
c[0:2] # 마지막 숫다 -1 인덱스의 값이 나온다.
# Out:
# [1, 2]

# %%
c[:2] #:콜론 앞에 생략 시 '0'부터 출력
# Out:
# [1, 2]

# %%
c[2:] # : 콜론 뒤에 생략 시 시작점 부터 끝 까지 출력
# Out:
# [3, 4, 5, 6]

# %%
# 리스트 더하기
d = [1,2,3]
e = [4,5,6]
f = d + e
print(f)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 리스트 곱하기
g = e * 2
print(g)
# Out:
# [4, 5, 6, 4, 5, 6]

# %%
# 리스트 길이 구하기
len(g)
# Out:
# 6

# %%
# 초보자가 범하기 쉬운 리스트 연산 오류
h = [ 1,2,3]
h[2] + "hi"  # 정수와 문자는 연산 X
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 3
#       1 # 초보자가 범하기 쉬운 리스트 연산 오류
#       2 h = [ 1,2,3]
# ----> 3 h[2] + "hi"  # 정수와 문자는 연산 X
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(h[2])+"hi"
#문자로 강제 변환 시켜주는 str 붙여준다

# %%
# 리스트에 C R U D
# create , 생성 , 추가 , 삽입 *.append()
# read , 읽기, 보기, 전체리스트  *.index()
# update , 자료수정  * a = b 수정
# delete , 자료 삭제 * del 변수[자리값] / .remove(3)/ .pop

# %%
#리스트에 자료를 추가해보자 , 변수.append * 회원가입시 새로 등록할때 변수 항목에 맨 뒤에 추가됨
ids = ["kjy", "yky", "kbs"]
ids.append("mbc")
print(ids)

# %%
passwords = ['1234','4567','7890']
passwords.append('8888')
print(passwords)
# Out:
# ['1234', '4567', '7890', '8888']

# %%
#리스트에 있는 값 가져오기
ids.index("mbc")
# Out:
# 3

# %%
passwords[3]
# Out:
# '8888'

# %%
# 알아온 password 값을 4486으로 수정해본다.
passwords[3] = "4486" # 문자로 입력했으니 따옴표 같이 써주기
print(passwords)
# Out:
# ['1234', '4567', '7890', '4486']

# %%
# 삭제하는 del변수[주소] / .remove / .pop
# 세번째 인덱스에 암호 삭제해본다.
passwords.pop(2)
# Out:
# '4486'

# %%
#pop 은 삭제되는 내용을 출력하고 삭제한다.
#passwords.pop() -> 맨마지막 자료를 삭제
#passwords.pop(2) -> 2 인덱스 삭제
passwords.pop(2)
# Out:
# '7890'

# %%
print(passwords)
# Out:
# ['1234', '4567', '4486']

# %%
# 리스트 정렬 변수.sort , 마지막에 데이터 정리할 때
# 리스트 뒤집기 변수.reverse , 있는 그대로 상태에서 앞 뒤뒤집는다
# 인덱스 반환 , 없는건 오류
# 리스트 요소 삽입 insert 변수.insert(넣을자리인덱스,넣을요소)

# %%
a = [1,2,3,4,5]
a.insert(2,"4-1")
a
# Out:
# [1, 2, '4-1', 3, 4, 5]

# %%
# 리스트 요소 제거 remove , 변수.remove(지울 요소,인덱스아님)
z = [1,2,3,4,5,6,7]
z.remove(4)
print(z)
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
# 리스트 요소 끄집어내기 변수.pop(지울요소, 인덱스아님)

# %%
# 리스트 확장 변수.extend(추가시킬변수)
