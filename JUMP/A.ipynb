# %%
# 변수명 규칙
# 영문자 (소문자로 시작) , 숫자 , 언더스코어만(_), 만 사용할 수 있다.
# 숫자로 시작할 수 없다.
# 예약어는 사용할 수 없다.
# 대소문자 구분한다.

# 올바른 변수명 예시
name = "홍길동"
age = 25
user_name = "gildong"
userName = "gildong"  # 카멜 케이스
_private = "비공개"
count1 = 10

#예약어 사용 X
#False, None, True, and, as, assert, break, class, continue, def,
#del, elif, else, except, finally, for, from, global, if, import,
#in, is, lambda, nonlocal, not, or, pass, raise, return, try,
#while, with, yield

#의미가 명확한 이름 사용
#단어 사이에 언더스코어 사용권장
#너무 짧거나 긴이름은 피한다

# %%
a = [1,2,3]
id(a)
# Out:
# 2898761055424

# %%
b=a
id(b) #대체해도 둘이 가르키는 대상의 객체는 같다
# Out:
# 2898761055424

# %%
a is b #a와 b가 가르키는 객체가 같다. #둘중하나 변경 시 같이 변경된다 , 같은 객체 변경이니까
# Out:
# True

# %%
a = [1,2,3,4]
b = a[:]
a[1] = 5
print(b)
# Out:
# [1, 2, 3, 4]

# %%
# copy module 사용 방법 from copy important copy

# %%
 #a, b = ('python' , 'life')
#(a, b ) = 'python' , 'life'
